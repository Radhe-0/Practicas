# %% [markdown]
# <a href="https://colab.research.google.com/github/Radhe-0/Practicas/blob/main/Practicas_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prácticas Numpy

# %% [markdown]
# ## Generadores de Datos

# %% [markdown]
# $\textbf{Estos generadores están en un repositorio de github que creé:}$
#
# [Generadores](https://github.com/Radhe-0/Generadores)

# %%
# Importo las librerías que usaré
import numpy as np
import pandas as pd

# %%
# Generador para Datos lineales

def DatosLineales(num=10):

    x = 2 * np.random.rand(num,1)
    x_ = [float(i) for i in x]
    y = np.random.randint(1,10) + np.random.randint(4,10) * x + np.random.randn(num,1)
    y_ = [float(i) for i in y]
    lista = []
    
    for i in zip(x_,y_):
        lista.append(i)

    return lista

datos = DatosLineales(500)
df = pd.DataFrame(datos, columns=['x','y'])
df
# Out:
#             x         y
# 0    1.678707  8.777435
# 1    0.528007  4.522460
# 2    1.346494  7.130345
# 3    1.119873  6.323051
# 4    0.512043  4.333665
# ..        ...       ...
# 495  1.541999  8.395444
# 496  0.421098  4.996182
# 497  0.028713  3.912415
# 498  1.066080  6.937060
# 499  0.319459  2.002404
#
# [500 rows x 2 columns]

# %%
df.plot.scatter(x='x',y='y')

# %%
# Generador de datos no lineales

def DatosNoLineales(num=10):

    x = 2 * np.random.rand(num,1)
    x_ = [float(i) for i in x]
    y = x + 2 * x ** 3 + np.random.randn(num,1)
    y_ = [float(i) for i in y]
    lista = []
    
    for i in zip(x_,y_):
        lista.append(i)

    return lista

datos = DatosNoLineales(200)
df = pd.DataFrame(datos, columns=['x','y'])
df
# Out:
#             x          y
# 0    0.326858  -0.883719
# 1    1.048514   2.238092
# 2    0.519411   0.297457
# 3    1.565804   9.557564
# 4    0.297462   2.652793
# ..        ...        ...
# 195  0.262643   0.898878
# 196  1.937693  15.699020
# 197  0.772015   3.094770
# 198  1.657434   9.580713
# 199  1.968954  18.458352
#
# [200 rows x 2 columns]

# %%
df.plot.scatter(x='x',y='y')

# %%
# Generadores de datos para practicar clasificación

def DatosClusters(num=10):

    numeros = np.random.rand(num)
    int_x = np.random.randint(0,100,size=num)
    int_y = np.random.randint(0,100,size=num)
    eje_x = np.sum([int_x, numeros], axis=0)
    eje_y = np.sum([int_y, numeros], axis=0)
    puntos = []

    for i in zip(eje_x, eje_y):
        puntos.append(i)
    
    return puntos

datos = DatosClusters(500)
df = pd.DataFrame(datos, columns=['x','y'])
df
# Out:
#              x          y
# 0    35.907300  81.907300
# 1    49.538259  20.538259
# 2     1.962868  10.962868
# 3    14.652201  50.652201
# 4    19.192909  40.192909
# ..         ...        ...
# 495  34.326565  63.326565
# 496  25.154289  46.154289
# 497  67.695843  42.695843
# 498  93.839658  40.839658
# 499  27.744498  84.744498
#
# [500 rows x 2 columns]

# %%
df.plot.scatter(x='x',y='y')

# %%
# Este generador es para clasificadores del tipo Logistic Regression
def DatosLRegression(num=10):

    ceros = np.zeros(num)
    random_1 = np.random.rand(num)
    random_2 = np.random.randint(1,6,size=(1,num))
    valores = random_2 + random_1
    lista = []

    for i in zip(valores[0], ceros):
        lista.append(i)

    unos = np.ones(num)
    random_3 = np.random.rand(num)
    random_4 = np.random.randint(6,11,size=(1,num))
    valores_2 = random_4 + random_3

    for i in zip(valores_2[0], unos):
        lista.append(i)
    
    return lista

datos = DatosLRegression(20)
df = pd.DataFrame(datos, columns=['x','y'])
df.head(10)
# Out:
#           x    y
# 0  2.581541  0.0
# 1  2.151238  0.0
# 2  4.177095  0.0
# 3  2.915071  0.0
# 4  2.356315  0.0
# 5  1.403155  0.0
# 6  2.935964  0.0
# 7  4.230151  0.0
# 8  1.926454  0.0
# 9  3.158415  0.0

# %%
df.plot.scatter(x='x',y='y')

# %%
# Más datos para clasificadores
def DatosSVM(num=10):

    X = (np.r_[np.random.randn(num, 2) - [2, 2], np.random.randn(num, 2) + [2, 2]]).reshape(-1)
    Y = (np.r_[np.random.randn(num, 2) - [2, 2], np.random.randn(num, 2) + [2, 2]]).reshape(-1)
    lista = []

    for i in zip(X,Y):
        lista.append(i)

    return lista

datos = DatosSVM(150)
df = pd.DataFrame(datos, columns=['x','y'])
df
# Out:
#             x         y
# 0   -2.949169 -2.900628
# 1   -1.464083 -2.306762
# 2   -1.210188 -2.170646
# 3   -2.895267 -2.993443
# 4   -1.804225 -0.966211
# ..        ...       ...
# 595  0.297260  2.405274
# 596  2.176990  2.693329
# 597  1.417418  0.273155
# 598  1.774842  1.993047
# 599  1.404864  0.098102
#
# [600 rows x 2 columns]

# %%
df.plot.scatter(x='x',y='y')

# %%
# Este es bastante específico, es para generar datos de alturas de personas, en una distribución normal

def DatosAltura(num=10):

    alturas = np.random.normal(1.70,0.16,num)
    personas = np.linspace(0,1,num)
    lista = []

    for i in zip(alturas,personas):
        lista.append(i)
    
    return lista

datos = DatosAltura(500)
df = pd.DataFrame(datos, columns=['x','y'])
df
# Out:
#             x         y
# 0    1.757332  0.000000
# 1    1.716395  0.002004
# 2    1.614046  0.004008
# 3    1.601700  0.006012
# 4    1.606702  0.008016
# ..        ...       ...
# 495  1.820540  0.991984
# 496  1.831113  0.993988
# 497  1.524265  0.995992
# 498  1.632942  0.997996
# 499  1.725312  1.000000
#
# [500 rows x 2 columns]

# %%
df.plot.scatter(x='x',y='y')
